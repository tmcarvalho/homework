# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pickle

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
def read_dataframe(filename):
    
    df = pd.read_parquet(filename)
    
    df['duration'] = df.dropOff_datetime - df.pickup_datetime
    df['duration'] = df['duration'].apply(lambda td: td.total_seconds()/60)
    
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    categorical = ['PUlocationID', 'DOlocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('../data/fhv_tripdata_2021-01.parquet')
df_val = read_dataframe('../data/fhv_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (1109826, 990113)

# %%
df_train
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00009 2021-01-01 00:27:00 2021-01-01 00:44:00
# 1                     B00009 2021-01-01 00:50:00 2021-01-01 01:07:00
# 3                     B00037 2021-01-01 00:13:09 2021-01-01 00:21:26
# 4                     B00037 2021-01-01 00:38:31 2021-01-01 00:53:44
# 5                     B00037 2021-01-01 00:59:02 2021-01-01 01:08:05
# ...                      ...                 ...                 ...
# 1154107               B03266 2021-01-31 23:43:03 2021-01-31 23:51:48
# 1154108               B03284 2021-01-31 23:50:27 2021-02-01 00:48:03
# 1154109      B03285          2021-01-31 23:13:46 2021-01-31 23:29:58
# 1154110      B03285          2021-01-31 23:58:03 2021-02-01 00:17:29
# 1154111               B03321 2021-01-31 23:39:00 2021-02-01 00:15:00
#
#         PUlocationID DOlocationID SR_Flag Affiliated_base_number   duration
# 0                nan          nan    None                 B00009  17.000000
# 1                nan          nan    None                 B00009  17.000000
# 3                nan         72.0    None                 B00037   8.283333
# 4                nan         61.0    None                 B00037  15.216667
# 5                nan         71.0    None                 B00037   9.050000
# ...              ...          ...     ...                    ...        ...
# 1154107          7.0          7.0    None                 B03266   8.750000
# 1154108         44.0         91.0    None                         57.600000
# 1154109        171.0        171.0    None        B03285           16.200000
# 1154110         15.0         15.0    None        B03285           19.433333
# 1154111          nan          nan    None                 B03321  36.000000
#
# [1109826 rows x 8 columns]

# %%
df_train.duration.mean()
# Out:
# 16.247253368247375

# %%
df_train.isnull().sum()/len(df_train)
# Out:
# dispatching_base_num      0.000000
# pickup_datetime           0.000000
# dropOff_datetime          0.000000
# PUlocationID              0.000000
# DOlocationID              0.000000
# SR_Flag                   1.000000
# Affiliated_base_number    0.000697
# duration                  0.000000
# dtype: float64

# %%
df_train.PUlocationID = df_train.PUlocationID.replace('nan', -1)
df_train.DOlocationID = df_train.DOlocationID.replace('nan', -1)
df_val.PUlocationID = df_val.PUlocationID.replace('nan', -1)
df_val.DOlocationID = df_val.DOlocationID.replace('nan', -1)

# %%
df_train.PUlocationID.describe()
# Out:
# count     1109826
# unique        262
# top            -1
# freq       927008
# Name: PUlocationID, dtype: int64

# %%
categorical = ['PUlocationID', 'DOlocationID']
#numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical].to_dict(orient='records')
x_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical].to_dict(orient='records')
x_val = dv.transform(val_dicts)

# %%
train_dicts
# Out:
# [{'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '71.0'},
#  {'PUlocationID': -1, 'DOlocationID': '91.0'},
#  {'PUlocationID': -1, 'DOlocationID': '39.0'},
#  {'PUlocationID': -1, 'DOlocationID': '37.0'},
#  {'PUlocationID': -1, 'DOlocationID': '39.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '89.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '67.0'},
#  {'PUlocationID': -1, 'DOlocationID': '22.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '122.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': '236.0', 'DOlocationID': '237.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': '196.0', 'DOlocationID': '196.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '174.0'},
#  {'PUlocationID': -1, 'DOlocationID': '248.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '42.0'},
#  {'PUlocationID': -1, 'DOlocationID': '248.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '32.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '127.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '121.0'},
#  {'PUlocationID': -1, 'DOlocationID': '240.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '248.0'},
#  {'PUlocationID': -1, 'DOlocationID': '20.0'},
#  {'PUlocationID': -1, 'DOlocationID': '242.0'},
#  {'PUlocationID': -1, 'DOlocationID': '200.0'},
#  {'PUlocationID': -1, 'DOlocationID': '182.0'},
#  {'PUlocationID': -1, 'DOlocationID': '208.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '70.0'},
#  {'PUlocationID': -1, 'DOlocationID': '70.0'},
#  {'PUlocationID': -1, 'DOlocationID': '129.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': '252.0', 'DOlocationID': '16.0'},
#  {'PUlocationID': '15.0', 'DOlocationID': '252.0'},
#  {'PUlocationID': '165.0', 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '42.0'},
#  {'PUlocationID': -1, 'DOlocationID': '223.0'},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '136.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': '70.0', 'DOlocationID': '173.0'},
#  {'PUlocationID': '173.0', 'DOlocationID': '173.0'},
#  {'PUlocationID': '260.0', 'DOlocationID': '82.0'},
#  {'PUlocationID': '143.0', 'DOlocationID': '142.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '159.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '136.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '147.0'},
#  {'PUlocationID': -1, 'DOlocationID': '116.0'},
#  {'PUlocationID': '115.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '221.0', 'DOlocationID': '115.0'},
#  {'PUlocationID': '115.0', 'DOlocationID': '245.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '221.0', 'DOlocationID': '221.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '187.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '221.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '187.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '187.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '221.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '221.0'},
#  {'PUlocationID': '115.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '221.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '221.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '258.0'},
#  {'PUlocationID': -1, 'DOlocationID': '210.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '37.0'},
#  {'PUlocationID': -1, 'DOlocationID': '258.0'},
#  {'PUlocationID': -1, 'DOlocationID': '70.0'},
#  {'PUlocationID': '181.0', 'DOlocationID': '189.0'},
#  {'PUlocationID': '189.0', 'DOlocationID': '181.0'},
#  {'PUlocationID': '181.0', 'DOlocationID': '228.0'},
#  {'PUlocationID': '166.0', 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '89.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '222.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '71.0'},
#  {'PUlocationID': -1, 'DOlocationID': '85.0'},
#  {'PUlocationID': -1, 'DOlocationID': '71.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '37.0'},
#  {'PUlocationID': -1, 'DOlocationID': '198.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '89.0'},
#  {'PUlocationID': -1, 'DOlocationID': '256.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '71.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '10.0'},
#  {'PUlocationID': -1, 'DOlocationID': '66.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '49.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '232.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': -1, 'DOlocationID': '108.0'},
#  {'PUlocationID': -1, 'DOlocationID': '152.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '37.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '91.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '220.0'},
#  {'PUlocationID': -1, 'DOlocationID': '174.0'},
#  {'PUlocationID': -1, 'DOlocationID': '153.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '3.0'},
#  {'PUlocationID': -1, 'DOlocationID': '241.0'},
#  {'PUlocationID': -1, 'DOlocationID': '265.0'},
#  {'PUlocationID': -1, 'DOlocationID': '200.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '220.0'},
#  {'PUlocationID': -1, 'DOlocationID': '241.0'},
#  {'PUlocationID': -1, 'DOlocationID': '136.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '106.0'},
#  {'PUlocationID': -1, 'DOlocationID': '37.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '116.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '141.0'},
#  {'PUlocationID': -1, 'DOlocationID': '141.0'},
#  {'PUlocationID': -1, 'DOlocationID': '113.0'},
#  {'PUlocationID': -1, 'DOlocationID': '265.0'},
#  {'PUlocationID': '129.0', 'DOlocationID': '129.0'},
#  {'PUlocationID': -1, 'DOlocationID': '196.0'},
#  {'PUlocationID': -1, 'DOlocationID': '132.0'},
#  {'PUlocationID': -1, 'DOlocationID': '10.0'},
#  {'PUlocationID': -1, 'DOlocationID': '134.0'},
#  {'PUlocationID': -1, 'DOlocationID': '134.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '28.0'},
#  {'PUlocationID': -1, 'DOlocationID': '129.0'},
#  {'PUlocationID': -1, 'DOlocationID': '258.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '258.0'},
#  {'PUlocationID': -1, 'DOlocationID': '102.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': -1, 'DOlocationID': '136.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '152.0'},
#  {'PUlocationID': -1, 'DOlocationID': '3.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '136.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '147.0'},
#  {'PUlocationID': -1, 'DOlocationID': '89.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '47.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '32.0'},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': -1, 'DOlocationID': '147.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '248.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '47.0'},
#  {'PUlocationID': -1, 'DOlocationID': '32.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '147.0'},
#  {'PUlocationID': -1, 'DOlocationID': '198.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '116.0'},
#  {'PUlocationID': -1, 'DOlocationID': '116.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': '142.0', 'DOlocationID': '142.0'},
#  {'PUlocationID': '142.0', 'DOlocationID': '200.0'},
#  {'PUlocationID': '211.0', 'DOlocationID': '107.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '189.0'},
#  {'PUlocationID': -1, 'DOlocationID': '112.0'},
#  {'PUlocationID': -1, 'DOlocationID': '40.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '21.0'},
#  {'PUlocationID': -1, 'DOlocationID': '241.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '153.0'},
#  {'PUlocationID': -1, 'DOlocationID': '153.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '174.0'},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '75.0'},
#  {'PUlocationID': -1, 'DOlocationID': '42.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '174.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '212.0'},
#  {'PUlocationID': -1, 'DOlocationID': '212.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '3.0'},
#  {'PUlocationID': -1, 'DOlocationID': '212.0'},
#  {'PUlocationID': -1, 'DOlocationID': '248.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '75.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '159.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '241.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '59.0'},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '20.0'},
#  {'PUlocationID': -1, 'DOlocationID': '265.0'},
#  {'PUlocationID': -1, 'DOlocationID': '265.0'},
#  {'PUlocationID': -1, 'DOlocationID': '147.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '95.0'},
#  {'PUlocationID': -1, 'DOlocationID': '10.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '97.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '3.0'},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '152.0'},
#  {'PUlocationID': -1, 'DOlocationID': '159.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '51.0'},
#  {'PUlocationID': -1, 'DOlocationID': '74.0'},
#  {'PUlocationID': -1, 'DOlocationID': '10.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': -1, 'DOlocationID': '74.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '265.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '3.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '212.0'},
#  {'PUlocationID': -1, 'DOlocationID': '41.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '42.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '116.0'},
#  {'PUlocationID': -1, 'DOlocationID': '256.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '217.0'},
#  {'PUlocationID': -1, 'DOlocationID': '39.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '217.0'},
#  {'PUlocationID': -1, 'DOlocationID': '217.0'},
#  {'PUlocationID': -1, 'DOlocationID': '36.0'},
#  {'PUlocationID': -1, 'DOlocationID': '36.0'},
#  {'PUlocationID': -1, 'DOlocationID': '36.0'},
#  {'PUlocationID': -1, 'DOlocationID': '39.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': -1, 'DOlocationID': '134.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '123.0'},
#  {'PUlocationID': -1, 'DOlocationID': '217.0'},
#  {'PUlocationID': -1, 'DOlocationID': '232.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '174.0'},
#  {'PUlocationID': -1, 'DOlocationID': '241.0'},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '208.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '250.0'},
#  {'PUlocationID': -1, 'DOlocationID': '116.0'},
#  {'PUlocationID': -1, 'DOlocationID': '166.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '120.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '159.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '116.0'},
#  {'PUlocationID': -1, 'DOlocationID': '42.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '174.0'},
#  {'PUlocationID': -1, 'DOlocationID': '47.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '147.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': '72.0', 'DOlocationID': '72.0'},
#  {'PUlocationID': '72.0', 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '236.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '216.0'},
#  {'PUlocationID': -1, 'DOlocationID': '216.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '258.0'},
#  {'PUlocationID': -1, 'DOlocationID': '191.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '106.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '215.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '216.0'},
#  {'PUlocationID': -1, 'DOlocationID': '258.0'},
#  {'PUlocationID': -1, 'DOlocationID': '215.0'},
#  {'PUlocationID': -1, 'DOlocationID': '258.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '201.0'},
#  {'PUlocationID': -1, 'DOlocationID': '28.0'},
#  {'PUlocationID': -1, 'DOlocationID': '216.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '82.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '131.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '258.0'},
#  {'PUlocationID': -1, 'DOlocationID': '129.0'},
#  {'PUlocationID': -1, 'DOlocationID': '134.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '108.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '129.0'},
#  {'PUlocationID': -1, 'DOlocationID': '56.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '70.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '136.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '127.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '10.0'},
#  {'PUlocationID': -1, 'DOlocationID': '216.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '215.0'},
#  {'PUlocationID': '129.0', 'DOlocationID': '56.0'},
#  {'PUlocationID': -1, 'DOlocationID': '26.0'},
#  {'PUlocationID': -1, 'DOlocationID': '227.0'},
#  {'PUlocationID': -1, 'DOlocationID': '26.0'},
#  {'PUlocationID': -1, 'DOlocationID': '67.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '67.0'},
#  {'PUlocationID': -1, 'DOlocationID': '22.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '223.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '155.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '197.0'},
#  {'PUlocationID': -1, 'DOlocationID': '10.0'},
#  {'PUlocationID': -1, 'DOlocationID': '120.0'},
#  {'PUlocationID': -1, 'DOlocationID': '47.0'},
#  {'PUlocationID': -1, 'DOlocationID': '116.0'},
#  {'PUlocationID': -1, 'DOlocationID': '47.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '116.0'},
#  {'PUlocationID': -1, 'DOlocationID': '93.0'},
#  {'PUlocationID': -1, 'DOlocationID': '92.0'},
#  {'PUlocationID': -1, 'DOlocationID': '129.0'},
#  {'PUlocationID': -1, 'DOlocationID': '196.0'},
#  {'PUlocationID': -1, 'DOlocationID': '170.0'},
#  {'PUlocationID': -1, 'DOlocationID': '93.0'},
#  {'PUlocationID': -1, 'DOlocationID': '129.0'},
#  {'PUlocationID': -1, 'DOlocationID': '232.0'},
#  {'PUlocationID': -1, 'DOlocationID': '121.0'},
#  {'PUlocationID': -1, 'DOlocationID': '260.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '41.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '127.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '248.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '127.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '250.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '220.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '165.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '56.0'},
#  {'PUlocationID': -1, 'DOlocationID': '21.0'},
#  {'PUlocationID': -1, 'DOlocationID': '82.0'},
#  {'PUlocationID': -1, 'DOlocationID': '152.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '152.0'},
#  {'PUlocationID': -1, 'DOlocationID': '42.0'},
#  {'PUlocationID': -1, 'DOlocationID': '159.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '213.0'},
#  {'PUlocationID': -1, 'DOlocationID': '159.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': -1, 'DOlocationID': '42.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '202.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '97.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': -1, 'DOlocationID': '192.0'},
#  {'PUlocationID': '129.0', 'DOlocationID': '76.0'},
#  {'PUlocationID': '56.0', 'DOlocationID': '70.0'},
#  {'PUlocationID': '226.0', 'DOlocationID': '226.0'},
#  {'PUlocationID': '173.0', 'DOlocationID': '173.0'},
#  {'PUlocationID': '129.0', 'DOlocationID': '129.0'},
#  {'PUlocationID': '56.0', 'DOlocationID': '173.0'},
#  {'PUlocationID': '129.0', 'DOlocationID': '260.0'},
#  {'PUlocationID': '56.0', 'DOlocationID': '56.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': '92.0', 'DOlocationID': '56.0'},
#  {'PUlocationID': '92.0', 'DOlocationID': '92.0'},
#  {'PUlocationID': '92.0', 'DOlocationID': '92.0'},
#  {'PUlocationID': '73.0', 'DOlocationID': '227.0'},
#  {'PUlocationID': '51.0', 'DOlocationID': '171.0'},
#  {'PUlocationID': -1, 'DOlocationID': '21.0'},
#  {'PUlocationID': -1, 'DOlocationID': '22.0'},
#  {'PUlocationID': -1, 'DOlocationID': '21.0'},
#  {'PUlocationID': -1, 'DOlocationID': '21.0'},
#  {'PUlocationID': -1, 'DOlocationID': '108.0'},
#  {'PUlocationID': -1, 'DOlocationID': '21.0'},
#  {'PUlocationID': -1, 'DOlocationID': '21.0'},
#  {'PUlocationID': -1, 'DOlocationID': '107.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '265.0'},
#  {'PUlocationID': -1, 'DOlocationID': '227.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '247.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '155.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '178.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '71.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': '55.0', 'DOlocationID': -1},
#  {'PUlocationID': '55.0', 'DOlocationID': -1},
#  {'PUlocationID': '123.0', 'DOlocationID': -1},
#  {'PUlocationID': '150.0', 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '200.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '243.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': '210.0', 'DOlocationID': -1},
#  {'PUlocationID': '123.0', 'DOlocationID': -1},
#  {'PUlocationID': '210.0', 'DOlocationID': -1},
#  {'PUlocationID': '21.0', 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '69.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '119.0'},
#  {'PUlocationID': -1, 'DOlocationID': '20.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '198.0'},
#  {'PUlocationID': -1, 'DOlocationID': '93.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '198.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '102.0'},
#  {'PUlocationID': -1, 'DOlocationID': '56.0'},
#  {'PUlocationID': -1, 'DOlocationID': '198.0'},
#  {'PUlocationID': -1, 'DOlocationID': '235.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '147.0'},
#  {'PUlocationID': -1, 'DOlocationID': '147.0'},
#  {'PUlocationID': -1, 'DOlocationID': '47.0'},
#  {'PUlocationID': -1, 'DOlocationID': '32.0'},
#  {'PUlocationID': -1, 'DOlocationID': '74.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '74.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '41.0'},
#  {'PUlocationID': -1, 'DOlocationID': '42.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '208.0'},
#  {'PUlocationID': -1, 'DOlocationID': '20.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': '221.0', 'DOlocationID': '245.0'},
#  {'PUlocationID': '245.0', 'DOlocationID': '221.0'},
#  {'PUlocationID': '221.0', 'DOlocationID': '115.0'},
#  {'PUlocationID': '115.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '41.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '74.0'},
#  {'PUlocationID': -1, 'DOlocationID': '159.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '74.0'},
#  {'PUlocationID': -1, 'DOlocationID': '10.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': -1, 'DOlocationID': '74.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '3.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '49.0'},
#  {'PUlocationID': -1, 'DOlocationID': '71.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '10.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '62.0'},
#  {'PUlocationID': -1, 'DOlocationID': '39.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '97.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '39.0'},
#  {'PUlocationID': -1, 'DOlocationID': '233.0'},
#  {'PUlocationID': -1, 'DOlocationID': '85.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '49.0'},
#  {'PUlocationID': -1, 'DOlocationID': '123.0'},
#  {'PUlocationID': -1, 'DOlocationID': '71.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '37.0'},
#  {'PUlocationID': -1, 'DOlocationID': '122.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '71.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '62.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '85.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '25.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '91.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '133.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '227.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '22.0'},
#  {'PUlocationID': -1, 'DOlocationID': '39.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '22.0'},
#  {'PUlocationID': -1, 'DOlocationID': '22.0'},
#  {'PUlocationID': -1, 'DOlocationID': '22.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '80.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '146.0'},
#  {'PUlocationID': -1, 'DOlocationID': '56.0'},
#  {'PUlocationID': -1, 'DOlocationID': '20.0'},
#  {'PUlocationID': -1, 'DOlocationID': '198.0'},
#  {'PUlocationID': -1, 'DOlocationID': '36.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '216.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '85.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '47.0'},
#  {'PUlocationID': -1, 'DOlocationID': '47.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '129.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '198.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '182.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '47.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '78.0'},
#  {'PUlocationID': -1, 'DOlocationID': '60.0'},
#  {'PUlocationID': -1, 'DOlocationID': '74.0'},
#  {'PUlocationID': -1, 'DOlocationID': '10.0'},
#  {'PUlocationID': -1, 'DOlocationID': '265.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '167.0'},
#  {'PUlocationID': -1, 'DOlocationID': '74.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '244.0'},
#  {'PUlocationID': -1, 'DOlocationID': '51.0'},
#  {'PUlocationID': -1, 'DOlocationID': '174.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '126.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '3.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '215.0'},
#  {'PUlocationID': -1, 'DOlocationID': '265.0'},
#  {'PUlocationID': -1, 'DOlocationID': '254.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '18.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '259.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '22.0'},
#  {'PUlocationID': '115.0', 'DOlocationID': '245.0'},
#  {'PUlocationID': '245.0', 'DOlocationID': '221.0'},
#  {'PUlocationID': '221.0', 'DOlocationID': '115.0'},
#  {'PUlocationID': '115.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '221.0', 'DOlocationID': '214.0'},
#  {'PUlocationID': '221.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '115.0', 'DOlocationID': '245.0'},
#  {'PUlocationID': '115.0', 'DOlocationID': '115.0'},
#  {'PUlocationID': '221.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '206.0', 'DOlocationID': '156.0'},
#  {'PUlocationID': -1, 'DOlocationID': '37.0'},
#  {'PUlocationID': -1, 'DOlocationID': '198.0'},
#  {'PUlocationID': -1, 'DOlocationID': '177.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '63.0'},
#  {'PUlocationID': -1, 'DOlocationID': '149.0'},
#  {'PUlocationID': -1, 'DOlocationID': '108.0'},
#  {'PUlocationID': -1, 'DOlocationID': '210.0'},
#  {'PUlocationID': -1, 'DOlocationID': '89.0'},
#  {'PUlocationID': -1, 'DOlocationID': '89.0'},
#  {'PUlocationID': -1, 'DOlocationID': '123.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '159.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '159.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '129.0'},
#  {'PUlocationID': -1, 'DOlocationID': '56.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '70.0'},
#  {'PUlocationID': -1, 'DOlocationID': '168.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '36.0'},
#  {'PUlocationID': -1, 'DOlocationID': '173.0'},
#  {'PUlocationID': -1, 'DOlocationID': '70.0'},
#  {'PUlocationID': '223.0', 'DOlocationID': '223.0'},
#  {'PUlocationID': '7.0', 'DOlocationID': '7.0'},
#  {'PUlocationID': '17.0', 'DOlocationID': '206.0'},
#  {'PUlocationID': '132.0', 'DOlocationID': '231.0'},
#  {'PUlocationID': -1, 'DOlocationID': '188.0'},
#  {'PUlocationID': -1, 'DOlocationID': '71.0'},
#  {'PUlocationID': -1, 'DOlocationID': '189.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '85.0'},
#  {'PUlocationID': -1, 'DOlocationID': '77.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '36.0'},
#  {'PUlocationID': -1, 'DOlocationID': '198.0'},
#  {'PUlocationID': -1, 'DOlocationID': '36.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '133.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '22.0'},
#  {'PUlocationID': -1, 'DOlocationID': '72.0'},
#  {'PUlocationID': -1, 'DOlocationID': '181.0'},
#  {'PUlocationID': -1, 'DOlocationID': '49.0'},
#  {'PUlocationID': -1, 'DOlocationID': '225.0'},
#  {'PUlocationID': -1, 'DOlocationID': '49.0'},
#  {'PUlocationID': -1, 'DOlocationID': '61.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '228.0'},
#  {'PUlocationID': -1, 'DOlocationID': '14.0'},
#  {'PUlocationID': -1, 'DOlocationID': '261.0'},
#  {'PUlocationID': -1, 'DOlocationID': '76.0'},
#  {'PUlocationID': -1, 'DOlocationID': '195.0'},
#  {'PUlocationID': -1, 'DOlocationID': '130.0'},
#  {'PUlocationID': -1, 'DOlocationID': '232.0'},
#  {'PUlocationID': -1, 'DOlocationID': '139.0'},
#  {'PUlocationID': -1, 'DOlocationID': '139.0'},
#  {'PUlocationID': -1, 'DOlocationID': '35.0'},
#  {'PUlocationID': -1, 'DOlocationID': '17.0'},
#  {'PUlocationID': -1, 'DOlocationID': '179.0'},
#  {'PUlocationID': '233.0', 'DOlocationID': '140.0'},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': -1},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '94.0'},
#  {'PUlocationID': -1, 'DOlocationID': '248.0'},
#  {'PUlocationID': -1, 'DOlocationID': '81.0'},
#  {'PUlocationID': -1, 'DOlocationID': '212.0'},
#  {'PUlocationID': -1, 'DOlocationID': '169.0'},
#  {'PUlocationID': -1, 'DOlocationID': '248.0'},
#  ...]

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)

y_pred = lr.predict(x_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 10.528519107211805

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)

y_pred = lr.predict(x_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 11.014283195752167

# %%
with open('../models/lin_reg_homework1.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)
